# %%
import pandas as pd

# %%
df =pd.read_csv("cleaned_dataset.csv")

# %%
df.head()
# Out:
#       OrderID   OrderDate  CustomerID  CustomerName ProductID  \
# 0  ORD0075722  2022-12-22  CUST006588   Sahil Gupta    P00003
# 1  ORD0080185  2023-05-12  CUST005827   Pooja Patel    P00032
# 2  ORD0019865  2021-09-08  CUST019087   Arjun Kumar    P00014
# 3  ORD0076700  2023-03-12  CUST000432    Aman Kumar    P00034
# 4  ORD0092992  2022-09-10  CUST011736  Aarav Sharma    P00016
#
#        ProductName        Category     Brand  Quantity  UnitPrice  Discount  \
# 0  Smartphone Case        Clothing    Zenith         4     298.45      0.05
# 1       Board Game    Toys & Games  ReadMore         2     154.48      0.00
# 2       Drone Mini  Home & Kitchen      Apex         3     400.34      0.05
# 3   Desk Organizer           Books      Apex         1     175.53      0.10
# 4        Air Fryer           Books  ReadMore         5     190.37      0.00
#
#    TotalAmount PaymentMethod OrderStatus          City        Country  \
# ...

# %%
cols_to_drop = ["CustomerName", "ProductName", "Category","Brand","PaymentMethod","OrderStatus","Country"]
df_new = df.drop(columns=cols_to_drop)

# %%
df_new.head()
# Out:
#       OrderID   OrderDate  CustomerID ProductID  Quantity  UnitPrice  \
# 0  ORD0075722  2022-12-22  CUST006588    P00003         4     298.45
# 1  ORD0080185  2023-05-12  CUST005827    P00032         2     154.48
# 2  ORD0019865  2021-09-08  CUST019087    P00014         3     400.34
# 3  ORD0076700  2023-03-12  CUST000432    P00034         1     175.53
# 4  ORD0092992  2022-09-10  CUST011736    P00016         5     190.37
#
#    Discount  TotalAmount          City   SellerID
# 0      0.05      1144.54      Columbus  SELL01349
# 1      0.00       341.31  Jacksonville  SELL00680
# 2      0.05      1243.58       Chicago  SELL00556
# 3      0.10       175.42       Houston  SELL00299
# 4      0.00      1077.22     Charlotte  SELL01625

# %%
df_new.to_csv("clean_dataset_numeric.csv", index=False)
