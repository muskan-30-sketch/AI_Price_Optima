# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("cleaned_dataset.csv")

# %%
df.head()
# Out:
#       OrderID   OrderDate  CustomerID  CustomerName ProductID  \
# 0  ORD0075722  2022-12-22  CUST006588   Sahil Gupta    P00003
# 1  ORD0080185  2023-05-12  CUST005827   Pooja Patel    P00032
# 2  ORD0019865  2021-09-08  CUST019087   Arjun Kumar    P00014
# 3  ORD0076700  2023-03-12  CUST000432    Aman Kumar    P00034
# 4  ORD0092992  2022-09-10  CUST011736  Aarav Sharma    P00016
#
#        ProductName        Category     Brand  Quantity  UnitPrice  Discount  \
# 0  Smartphone Case        Clothing    Zenith         4     298.45      0.05
# 1       Board Game    Toys & Games  ReadMore         2     154.48      0.00
# 2       Drone Mini  Home & Kitchen      Apex         3     400.34      0.05
# 3   Desk Organizer           Books      Apex         1     175.53      0.10
# 4        Air Fryer           Books  ReadMore         5     190.37      0.00
#
#    TotalAmount PaymentMethod OrderStatus          City        Country  \
# ...

# %%
#created a numeric-only dataframe using select_dtypes for correlation and price fluctuation analysis, while keeping the original dataset for business insights.
numeric_df=df.select_dtypes(include='number')

# %%
numeric_df.info() #for correlation and ml models numeric data should use only
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Quantity     10000 non-null  int64
#  1   UnitPrice    10000 non-null  float64
#  2   Discount     10000 non-null  float64
#  3   TotalAmount  10000 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 312.6 KB

# %%
numeric_df.corr()
# Out:
#              Quantity  UnitPrice  Discount  TotalAmount
# Quantity     1.000000   0.006960  0.000384     0.595734
# UnitPrice    0.006960   1.000000  0.013968     0.717837
# Discount     0.000384   0.013968  1.000000    -0.102836
# TotalAmount  0.595734   0.717837 -0.102836     1.000000

# %%
sns.heatmap(numeric_df.corr(),annot=True) #dark colour shows strong relation
# Out:
# <Axes: >
